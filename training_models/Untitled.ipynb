# %%
# !ls /net/storage001.ib.cluster/om2/user/smadan/differentiable_graphics_ml/training_models
# Out:
# all_info_lenet.p
# all_preds.out
# analyzing_model_predictions.ipynb
# biased_experiment_IDs.sh
# biased_experiment_IDs_single_parameter.sh
# check.ipynb
# cma_utils.py
# configs
# data_dimension_experiment_10_100_1000.p
# data_dimension_experiment_10_repeats_bad_data.p
# data_dimension_experiment_10_repeats_good_data_fixed_initialization_seed_2.p
# data_dimension_experiment_10_repeats_good_data.p
# data_dimension_experiment_10_repeats.p
# data_dimension_experiment_20_2.p
# data_dimension_experiment_20.p
# data_dimension_experiment_4.p
# data_size_experiment_1_repeats_10000000.p
# data_size_experiment_5_repeats_10000000.p
# data_size_experiment_5_repeats_20_dim_2.p
# data_size_experiment_5_repeats_20_dim.p
# data_size_experiment_5_repeats_all.p
# data_size_experiment_5_repeats.p
# data_size_exp.out
# data_size_exp.py
# epoch_experiment_10_repeats.p
# evaluate_illumination_set.ipynb
# exploring_tf_records.ipynb
# failures_dim_100_basic.p
# histogram_closest_images.ipynb
# imagenet_classes.txt
# info_iters_linear.p
# info_iters.p
# inof.p
# investigating_predictions.ipynb
# leftover_bad_files.txt
# lightning_logs
# light_point_to_accuracies_large.p
# light_point_to_accuracies.p
# logs
# measure_accuracy.py
# measure_shift_accuracies.py
# normalized_models.sh
# outcmaes
# predict_all.sh
# prediction_results.txt
# predict_shift_accuracies.sh
# pretrained_inference.ipynb
# pretrained.ipynb
# __pycache__
# python_script.sh
# PyTorch-VAE
# resnet_40_experiments.sh
# resnet_attack_output.p
# resnet_uniform_data_20_epoch.pt
# saved_models
# shapenet_class_num_to_class_name.p
# shapenet_id_to_class_num.p
# shift_accuracies.txt
# shift_predictions.ipynb
# simCLR.ipynb
# slurm_outputs
# submit_biased_experiments.sh
# submit_python.sh
# submit_resnet_40_experiments.sh
# submit_transformer_experiments.sh
# test_model_predictions.ipynb
# test_model.pt
# toy_data.ipynb
# trained_MLPs.p
# training.out
# training_simple_CNN.ipynb
# training_simple_CNN.py
# training_simple_CNN_tfrecord.ipynb
# training_simple_CNN_tfrecords.py
# training_utils.py
# training_with_imagenet.ipynb
# train_test_splits_shapenet.ipynb
# transformer_experiments.sh
# uniform_2d_images_lenet.ipynb
# uniform_data_experiments
# uniform_data.ipynb
# uniform_data_simplified.ipynb
# uniform_experiment_results
# unsymmetric_biased.sh
# Untitled.ipynb
# VAE.ipynb
# vanilla_vae.py
# visualizing_dataset.ipynb
# wandb
# wandb_test.py

# %%
import pickle
import utils
import pickle
import utils
import numpy as np
import matplotlib.pyplot as plt
from utils import MLP
from utils import CMA_info


import torch
import random
import torch.nn as nn

import torch.distributions as D

import numpy as np
import cma
from tqdm.notebook import tqdm
import pickle

import matplotlib.pyplot as plt

import torch.nn.functional as F
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4b30e62929f3> in <module>
#       1 import pickle
# ----> 2 import utils
#       3 import pickle
#       4 import utils
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'utils'
